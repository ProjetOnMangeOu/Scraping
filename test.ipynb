# %%
import pandas as pd

# %%
df = pd.read_json("data.json")
df.describe()
# Out:
#            index
# count  25.000000
# mean   12.000000
# std     7.359801
# min     0.000000
# 25%     6.000000
# 50%    12.000000
# 75%    18.000000
# max    24.000000

# %%
df["nom"].value_counts()
# Out:
# nom
# Brasserie Galliaerde - (Anciennement "Aux Bretons")    3
# Restaurant Sébastopol                                  2
# La Fossetta                                            2
# Il Ristorante                                          2
# Quai 38                                                2
# Saveurs des Iles                                       2
# Estaminet Au Vieux De La Vieille                       2
# Les Fils à Maman Lille                                 2
# POGGIO                                                 2
# Le Ici Bar & Restaurant                                2
# Aspendos                                               2
# Au Cheval Blanc                                        1
# Estaminet Chez La Vieille                              1
# Name: count, dtype: int64

# %%
df
# Out:
#     index                                               link  \
# 0       0  https://www.google.fr/maps/place/Restaurant+S%...
# 1       1  https://www.google.fr/maps/place/La+Fossetta/d...
# 2       2  https://www.google.fr/maps/place/Pancook+Lille...
# 3       3  https://www.google.fr/maps/place/Il+Ristorante...
# 4       4  https://www.google.fr/maps/place/La+Table+de+S...
# 5       5  https://www.google.fr/maps/place/Quai+38/data=...
# 6       6  https://www.google.fr/maps/place/Aux+%C3%A9ph%...
# 7       7  https://www.google.fr/maps/place/Brasserie+Gal...
# 8       8  https://www.google.fr/maps/place/SOlange/data=...
# 9       9  https://www.google.fr/maps/place/Au+Cheval+Bla...
# 10     10  https://www.google.fr/maps/place/Le+Chantecler...
# 11     11  https://www.google.fr/maps/place/Saveurs+des+I...
# 12     12  https://www.google.fr/maps/place/Tramontana+Ri...
# 13     13  https://www.google.fr/maps/place/Estaminet+Au+...
# ...

# %%
df[df.duplicated("nom")]
# Out:
#     index                                               link  \
# 1       1  https://www.google.fr/maps/place/La+Fossetta/d...
# 3       3  https://www.google.fr/maps/place/Il+Ristorante...
# 5       5  https://www.google.fr/maps/place/Quai+38/data=...
# 7       7  https://www.google.fr/maps/place/Brasserie+Gal...
# 9       9  https://www.google.fr/maps/place/Au+Cheval+Bla...
# 10     10  https://www.google.fr/maps/place/Le+Chantecler...
# 13     13  https://www.google.fr/maps/place/Estaminet+Au+...
# 15     15  https://www.google.fr/maps/place/Les+Fils+%C3%...
# 17     17  https://www.google.fr/maps/place/POGGIO/data=!...
# 19     19  https://www.google.fr/maps/place/Le+Ici+Bar+%2...
# 21     21  https://www.google.fr/maps/place/Aspendos/data...
# 23     23  https://www.google.fr/maps/place/Estaminet+Che...
#
#                                                 image  \
# 1   https://lh5.googleusercontent.com/p/AF1QipPlFT...
# 3   https://lh5.googleusercontent.com/p/AF1QipNm6x...
# ...
